# %%
# !pip install pandas openpyxl

# %%
import pandas as pd

# %%
df = pd.read_excel("Consumer Price Index - Rural, Urban, Combined (State-Wise)_1.xlsx")
df.head()
# Out:
#       Month     State / Union Teritory Provisional/ Final Food and beverages  \
# 0       NaN                        NaN                NaN              Rural
# 1       NaN                        NaN                NaN              Index
# 2  Apr-2025                  ALL INDIA        Provisional              386.8
# 3  Apr-2025  ANDAMAN & NICOBAR ISLANDS        Provisional              426.2
# 4  Apr-2025             ANDHRA PRADESH        Provisional              391.4
#
#       Unnamed: 4 Food and beverages.1     Unnamed: 6 Food and beverages.2  \
# 0            NaN                Urban            NaN             Combined
# 1  Inflation (%)                Index  Inflation (%)                Index
# 2         104.12                  401         104.49                  392
# 3         109.64                387.4         103.25                410.2
# 4         100.72                  412         102.66                397.6
#
# ...

# %%
df.columns
# Out:
# Index(['Month', 'State / Union Teritory', 'Provisional/ Final',
#        'Food and beverages', 'Unnamed: 4', 'Food and beverages.1',
#        'Unnamed: 6', 'Food and beverages.2', 'Unnamed: 8',
#        ' Pan, Tobacco and Intoxicants', 'Unnamed: 10',
#        ' Pan, Tobacco and Intoxicants.1', 'Unnamed: 12',
#        ' Pan, Tobacco and Intoxicants.2', 'Unnamed: 14',
#        'Clothing and footwear', 'Unnamed: 16', 'Clothing and footwear.1',
#        'Unnamed: 18', 'Clothing and footwear.2', 'Unnamed: 20', ' Housing',
#        'Unnamed: 22', ' Housing.1', 'Unnamed: 24', ' Housing.2', 'Unnamed: 26',
#        ' Fuel and Light ', 'Unnamed: 28', ' Fuel and Light .1', 'Unnamed: 30',
#        ' Fuel and Light .2', 'Unnamed: 32', ' Miscellaneous', 'Unnamed: 34',
#        ' Miscellaneous.1', 'Unnamed: 36', ' Miscellaneous.2', 'Unnamed: 38',
#        ' General Index', 'Unnamed: 40', ' General Index.1', 'Unnamed: 42',
#        ' General Index.2', 'Unnamed: 44'],
#       dtype='object')
